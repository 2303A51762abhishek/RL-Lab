# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51762abhishek/RL-Lab/blob/main/RL_L_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 1
#
# Environment: CartPole
# Initial State: [-0.01556444  0.0055758  -0.01266164  0.0137112 ]
# Action Space: Discrete(2)
# Step: 1 Action: 0 Reward: 1.0 Next State: [-0.01545293 -0.1893623  -0.01238742  0.3023725 ]
# Step: 2 Action: 1 Reward: 1.0 Next State: [-0.01924017  0.00593399 -0.00633997  0.00580873]
# Step: 3 Action: 0 Reward: 1.0 Next State: [-0.01912149 -0.18909647 -0.00622379  0.2964846 ]
# Step: 4 Action: 0 Reward: 1.0 Next State: [-2.2903424e-02 -3.8412914e-01 -2.9410128e-04  5.8719814e-01]
# Step: 5 Action: 1 Reward: 1.0 Next State: [-0.03058601 -0.18900307  0.01144986  0.2944226 ]
# Step: 6 Action: 1 Reward: 1.0 Next State: [-0.03436607  0.00595379  0.01733831  0.00537267]
# Step: 7 Action: 0 Reward: 1.0 Next State: [-0.03424699 -0.18941247  0.01744577  0.30347523]
# Step: 8 Action: 1 Reward: 1.0 Next State: [-0.03803524  0.00545656  0.02351527  0.01634495]
# Step: 9 Action: 0 Reward: 1.0 Next State: [-0.03792611 -0.1899946   0.02384217  0.3163535 ]
# Step: 10 Action: 1 Reward: 1.0 Next State: [-0.041726    0.00477978  0.03016924  0.03128389]
# Step: 11 Action: 0 Reward: 1.0 Next State: [-0.04163041 -0.19076154  0.03079492  0.3333308 ]
# Step: 12 Action: 0 Reward: 1.0 Next State: [-0.04544564 -0.38630795  0.03746153  0.6355636 ]
# Step: 13 Action: 0 Reward: 1.0 Next State: [-0.05317179 -0.5819318   0.05017281  0.9398047 ]
# Step: 14 Action: 0 Reward: 1.0 Next State: [-0.06481043 -0.77769285  0.0689689   1.2478213 ]
# Step: 15 Action: 0 Reward: 1.0 Next State: [-0.08036429 -0.97362804  0.09392533  1.5612861 ]
# Step: 16 Action: 1 Reward: 1.0 Next State: [-0.09983685 -0.77974695  0.12515105  1.2993199 ]
# Step: 17 Action: 0 Reward: 1.0 Next State: [-0.11543179 -0.9762155   0.15113744  1.6284162 ]
# Step: 18 Action: 1 Reward: 1.0 Next State: [-0.13495609 -0.7831589   0.18370576  1.3863978 ]
# Step: 19 Action: 1 Reward: 1.0 Next State: [-0.15061928 -0.59073997  0.21143372  1.1563323 ]
#
# Episode Completed
# Total Steps: 19
# Total Reward: 19.0
# Average Reward: 1.0

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 2
#
# Environment: MountainCar
# Initial State: [-0.5797138  0.       ]
# Action Space: Discrete(3)
# Step: 1 Action: 0 Reward: -1.0 Next State: [-0.5802949  -0.00058112]
# Step: 2 Action: 2 Reward: -1.0 Next State: [-0.5794529   0.00084205]
# Step: 3 Action: 1 Reward: -1.0 Next State: [-0.5781939  0.001259 ]
# Step: 4 Action: 2 Reward: -1.0 Next State: [-0.57552725  0.00266663]
# Step: 5 Action: 2 Reward: -1.0 Next State: [-0.5714727   0.00405452]
# Step: 6 Action: 0 Reward: -1.0 Next State: [-0.5680604   0.00341235]
# Step: 7 Action: 0 Reward: -1.0 Next State: [-0.56531554  0.00274482]
# Step: 8 Action: 1 Reward: -1.0 Next State: [-0.56225866  0.00305688]
# Step: 192 Action: 1 Reward: -1.0 Next State: [-0.2860456  0.0009624]
# Step: 193 Action: 1 Reward: -1.0 Next State: [-0.28671783 -0.00067222]
# Step: 194 Action: 2 Reward: -1.0 Next State: [-0.28802085 -0.00130302]
# Step: 195 Action: 1 Reward: -1.0 Next State: [-0.29094726 -0.0029264 ]
# Step: 196 Action: 2 Reward: -1.0 Next State: [-0.2944803  -0.00353303]
# Step: 197 Action: 1 Reward: -1.0 Next State: [-0.29959956 -0.00511927]
# Step: 198 Action: 2 Reward: -1.0 Next State: [-0.3052752  -0.00567565]
# Step: 199 Action: 2 Reward: -1.0 Next State: [-0.3114737  -0.00619849]
# Step: 200 Action: 1 Reward: -1.0 Next State: [-0.3191579 -0.0076842]
#
# Episode Completed
# Total Steps: 200
# Total Reward: -200.0
# Average Reward: -1.0

# %%
import gymnasium as gym


def random_agent(env_name):

    # Create environment
    if env_name == "CartPole":
        env = gym.make("CartPole-v1")

    elif env_name == "MountainCar":
        env = gym.make("MountainCar-v0")

    elif env_name == "FrozenLake":
        env = gym.make("FrozenLake-v1", is_slippery=True)

    else:
        print("Invalid environment")
        return

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        print(
            "Step:", steps + 1,
            "Action:", action,
            "Reward:", reward,
            "Next State:", next_state
        )

        total_reward += reward
        steps += 1

        state = next_state

        if terminated or truncated:
            break

    # Calculate average reward
    average_reward = total_reward / steps

    print("\nEpisode Completed")
    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# -------------------------------------------------
# MAIN
# -------------------------------------------------

print("RANDOM AGENT - REINFORCEMENT LEARNING")

print("\n1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter choice: ")

if choice == "1":
    random_agent("CartPole")

elif choice == "2":
    random_agent("MountainCar")

elif choice == "3":
    random_agent("FrozenLake")

else:
    print("Invalid choice")
# Out:
# RANDOM AGENT - REINFORCEMENT LEARNING
#
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
#
# Enter choice: 3
#
# Environment: FrozenLake
# Initial State: 0
# Action Space: Discrete(4)
# Step: 1 Action: 0 Reward: 0 Next State: 0
# Step: 2 Action: 1 Reward: 0 Next State: 1
# Step: 3 Action: 1 Reward: 0 Next State: 0
# Step: 4 Action: 1 Reward: 0 Next State: 4
# Step: 5 Action: 0 Reward: 0 Next State: 8
# Step: 6 Action: 1 Reward: 0 Next State: 9
# Step: 7 Action: 1 Reward: 0 Next State: 8
# Step: 8 Action: 3 Reward: 0 Next State: 8
# Step: 9 Action: 1 Reward: 0 Next State: 8
# Step: 10 Action: 2 Reward: 0 Next State: 12
#
# Episode Completed
# Total Steps: 10
# Total Reward: 0
# Average Reward: 0.0
